# %% [markdown]
# # While Loop

# %%
a=5
while a<10:
    print('yes')
    a=a+1

# %%
b=5  
while b>1:
    print('yes')
    b=b-1

# %%
c=7
while c>2:
    print('hansraj_losal')
    c=c-1
    if c==4:
        break
# Out:
# hansraj_losal
# hansraj_losal
# hansraj_losal

# %%
e=20
while e<30:
    print("yes")
    e=e+1
else:
    print('no')
# Out:
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# no
